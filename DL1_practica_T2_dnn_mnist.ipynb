# %% [markdown]
# <a href="https://colab.research.google.com/github/hosamfa3096/repositorio_IA3/blob/main/DL1_practica_T2_dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006);

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (728)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
model= tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.5074 - accuracy: 0.8424 - val_loss: 0.2119 - val_accuracy: 0.9364
# Epoch 2/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.1563 - accuracy: 0.9545 - val_loss: 0.1400 - val_accuracy: 0.9593
# Epoch 3/35
# 118/118 [==============================] - 2s 19ms/step - loss: 0.1090 - accuracy: 0.9676 - val_loss: 0.1010 - val_accuracy: 0.9694
# Epoch 4/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0806 - accuracy: 0.9756 - val_loss: 0.1021 - val_accuracy: 0.9679
# Epoch 5/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0642 - accuracy: 0.9807 - val_loss: 0.0873 - val_accuracy: 0.9734
# Epoch 6/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0507 - accuracy: 0.9846 - val_loss: 0.0789 - val_accuracy: 0.9762
# Epoch 7/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0395 - accuracy: 0.9878 - val_loss: 0.0786 - val_accuracy: 0.9771
# Epoch 8/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0324 - accuracy: 0.9903 - val_loss: 0.0760 - val_accuracy: 0.9759
# Epoch 9/35
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0265 - accuracy: 0.9923 - val_loss: 0.0738 - val_accuracy: 0.9790
# Epoch 10/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.0730 - val_accuracy: 0.9796
# Epoch 11/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.0751 - val_accuracy: 0.9805
# Epoch 12/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0744 - val_accuracy: 0.9799
# Epoch 13/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.0770 - val_accuracy: 0.9795
# Epoch 14/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0805 - val_accuracy: 0.9804
# Epoch 15/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.0934 - val_accuracy: 0.9752
# Epoch 16/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0873 - val_accuracy: 0.9792
# Epoch 17/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0815 - val_accuracy: 0.9804
# Epoch 18/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0814 - val_accuracy: 0.9812
# Epoch 19/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.0869 - val_accuracy: 0.9804
# Epoch 20/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0869 - val_accuracy: 0.9811
# Epoch 21/35
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0842 - val_accuracy: 0.9812
# Epoch 22/35
# 118/118 [==============================] - 2s 14ms/step - loss: 6.9629e-04 - accuracy: 0.9999 - val_loss: 0.0834 - val_accuracy: 0.9825
# Epoch 23/35
# 118/118 [==============================] - 2s 14ms/step - loss: 3.2691e-04 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9828
# Epoch 24/35
# 118/118 [==============================] - 2s 14ms/step - loss: 2.6120e-04 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9828
# Epoch 25/35
# 118/118 [==============================] - 2s 14ms/step - loss: 2.0367e-04 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9831
# Epoch 26/35
# 118/118 [==============================] - 2s 14ms/step - loss: 1.7484e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9829
# Epoch 27/35
# 118/118 [==============================] - 2s 14ms/step - loss: 1.5550e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9826
# Epoch 28/35
# 118/118 [==============================] - 2s 14ms/step - loss: 1.3764e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9830
# Epoch 29/35
# 118/118 [==============================] - 2s 14ms/step - loss: 1.2494e-04 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9829
# Epoch 30/35
# 118/118 [==============================] - 2s 14ms/step - loss: 1.1523e-04 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9830
# Epoch 31/35
# 118/118 [==============================] - 2s 14ms/step - loss: 1.0615e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9829
# Epoch 32/35
# 118/118 [==============================] - 2s 14ms/step - loss: 9.5606e-05 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9827
# Epoch 33/35
# 118/118 [==============================] - 2s 14ms/step - loss: 8.7659e-05 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9826
# Epoch 34/35
# 118/118 [==============================] - 2s 14ms/step - loss: 8.1066e-05 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9827
# Epoch 35/35
# 118/118 [==============================] - 2s 14ms/step - loss: 7.3840e-05 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9825

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
tf.keras.backend.clear_session()
n_epochs = 50

# Crear modelo
model_with_l2= tf.keras.models.Sequential()
model_with_l2.add(tf.keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model_with_l2.add(tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model_with_l2.add(tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model_with_l2.add(tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model_with_l2.add(tf.keras.layers.Dense(10, activation='softmax'))

# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 3s 19ms/step - loss: 1.6998 - accuracy: 0.8418 - val_loss: 0.8737 - val_accuracy: 0.9122
# Epoch 2/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.8055 - accuracy: 0.9187 - val_loss: 0.7449 - val_accuracy: 0.9229
# Epoch 3/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.7115 - accuracy: 0.9296 - val_loss: 0.6635 - val_accuracy: 0.9386
# Epoch 4/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.6580 - accuracy: 0.9358 - val_loss: 0.6795 - val_accuracy: 0.9208
# Epoch 5/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.6280 - accuracy: 0.9399 - val_loss: 0.6053 - val_accuracy: 0.9411
# Epoch 6/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.5992 - accuracy: 0.9437 - val_loss: 0.6259 - val_accuracy: 0.9267
# Epoch 7/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.5828 - accuracy: 0.9430 - val_loss: 0.5685 - val_accuracy: 0.9440
# Epoch 8/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.5614 - accuracy: 0.9459 - val_loss: 0.5785 - val_accuracy: 0.9395
# Epoch 9/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.5529 - accuracy: 0.9461 - val_loss: 0.5386 - val_accuracy: 0.9456
# Epoch 10/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.5392 - accuracy: 0.9482 - val_loss: 0.5249 - val_accuracy: 0.9492
# Epoch 11/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.5271 - accuracy: 0.9495 - val_loss: 0.5318 - val_accuracy: 0.9432
# Epoch 12/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.5192 - accuracy: 0.9504 - val_loss: 0.5166 - val_accuracy: 0.9508
# Epoch 13/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.5082 - accuracy: 0.9519 - val_loss: 0.4987 - val_accuracy: 0.9503
# Epoch 14/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.5022 - accuracy: 0.9527 - val_loss: 0.5315 - val_accuracy: 0.9393
# Epoch 15/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4986 - accuracy: 0.9517 - val_loss: 0.4883 - val_accuracy: 0.9539
# Epoch 16/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4859 - accuracy: 0.9550 - val_loss: 0.4917 - val_accuracy: 0.9543
# Epoch 17/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4847 - accuracy: 0.9545 - val_loss: 0.4741 - val_accuracy: 0.9545
# Epoch 18/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4760 - accuracy: 0.9555 - val_loss: 0.4751 - val_accuracy: 0.9531
# Epoch 19/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4728 - accuracy: 0.9555 - val_loss: 0.4633 - val_accuracy: 0.9571
# Epoch 20/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4673 - accuracy: 0.9568 - val_loss: 0.4690 - val_accuracy: 0.9528
# Epoch 21/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4629 - accuracy: 0.9568 - val_loss: 0.4583 - val_accuracy: 0.9548
# Epoch 22/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4574 - accuracy: 0.9567 - val_loss: 0.4519 - val_accuracy: 0.9574
# Epoch 23/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4519 - accuracy: 0.9582 - val_loss: 0.4446 - val_accuracy: 0.9589
# Epoch 24/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4477 - accuracy: 0.9584 - val_loss: 0.4393 - val_accuracy: 0.9577
# Epoch 25/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4453 - accuracy: 0.9591 - val_loss: 0.4466 - val_accuracy: 0.9553
# Epoch 26/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4403 - accuracy: 0.9593 - val_loss: 0.4461 - val_accuracy: 0.9539
# Epoch 27/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4388 - accuracy: 0.9587 - val_loss: 0.4322 - val_accuracy: 0.9577
# Epoch 28/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4335 - accuracy: 0.9599 - val_loss: 0.4297 - val_accuracy: 0.9596
# Epoch 29/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.4306 - accuracy: 0.9604 - val_loss: 0.4490 - val_accuracy: 0.9515
# Epoch 30/50
# 118/118 [==============================] - 2s 15ms/step - loss: 0.4286 - accuracy: 0.9596 - val_loss: 0.4361 - val_accuracy: 0.9547
# Epoch 31/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4260 - accuracy: 0.9591 - val_loss: 0.4258 - val_accuracy: 0.9566
# Epoch 32/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4221 - accuracy: 0.9597 - val_loss: 0.4269 - val_accuracy: 0.9537
# Epoch 33/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.4157 - accuracy: 0.9615 - val_loss: 0.4184 - val_accuracy: 0.9588
# Epoch 34/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4148 - accuracy: 0.9606 - val_loss: 0.4131 - val_accuracy: 0.9574
# Epoch 35/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4139 - accuracy: 0.9606 - val_loss: 0.4177 - val_accuracy: 0.9586
# Epoch 36/50
# 118/118 [==============================] - 2s 16ms/step - loss: 0.4124 - accuracy: 0.9609 - val_loss: 0.4190 - val_accuracy: 0.9561
# Epoch 37/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4080 - accuracy: 0.9623 - val_loss: 0.4151 - val_accuracy: 0.9565
# Epoch 38/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4064 - accuracy: 0.9617 - val_loss: 0.4169 - val_accuracy: 0.9582
# Epoch 39/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.4075 - accuracy: 0.9606 - val_loss: 0.4060 - val_accuracy: 0.9583
# Epoch 40/50
# 118/118 [==============================] - 2s 20ms/step - loss: 0.4018 - accuracy: 0.9621 - val_loss: 0.3956 - val_accuracy: 0.9617
# Epoch 41/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3978 - accuracy: 0.9625 - val_loss: 0.3926 - val_accuracy: 0.9634
# Epoch 42/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3981 - accuracy: 0.9620 - val_loss: 0.4185 - val_accuracy: 0.9545
# Epoch 43/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3936 - accuracy: 0.9631 - val_loss: 0.3941 - val_accuracy: 0.9600
# Epoch 44/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3919 - accuracy: 0.9630 - val_loss: 0.4197 - val_accuracy: 0.9504
# Epoch 45/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3902 - accuracy: 0.9628 - val_loss: 0.3942 - val_accuracy: 0.9590
# Epoch 46/50
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3897 - accuracy: 0.9635 - val_loss: 0.4015 - val_accuracy: 0.9588
# Epoch 47/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3922 - accuracy: 0.9617 - val_loss: 0.3853 - val_accuracy: 0.9615
# Epoch 48/50
# 118/118 [==============================] - 3s 30ms/step - loss: 0.3827 - accuracy: 0.9641 - val_loss: 0.3861 - val_accuracy: 0.9619
# Epoch 49/50
# 118/118 [==============================] - 3s 22ms/step - loss: 0.3814 - accuracy: 0.9638 - val_loss: 0.3961 - val_accuracy: 0.9591
# Epoch 50/50
# 118/118 [==============================] - 4s 36ms/step - loss: 0.3808 - accuracy: 0.9643 - val_loss: 0.3846 - val_accuracy: 0.9612

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
model_with_dp= tf.keras.models.Sequential()
model_with_dp.add(tf.keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model_with_dp.add(tf.keras.layers.Dropout(0.4))

model_with_dp.add(tf.keras.layers.Dense(128, activation='relu'))
model_with_dp.add(tf.keras.layers.Dropout(0.4))

model_with_dp.add(tf.keras.layers.Dense(64, activation='relu'))
model_with_dp.add(tf.keras.layers.Dropout(0.4))

model_with_dp.add(tf.keras.layers.Dense(32, activation='relu'))
model_with_dp.add(tf.keras.layers.Dropout(0.4))

model_with_dp.add(tf.keras.layers.Dense(10, activation='softmax'))

# Compilamos el modelo
model_with_dp.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_with_dp.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 118/118 [==============================] - 3s 18ms/step - loss: 0.9014 - accuracy: 0.7048 - val_loss: 0.2484 - val_accuracy: 0.9360
# Epoch 2/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3890 - accuracy: 0.9046 - val_loss: 0.1765 - val_accuracy: 0.9540
# Epoch 3/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.3178 - accuracy: 0.9256 - val_loss: 0.1523 - val_accuracy: 0.9631
# Epoch 4/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2707 - accuracy: 0.9353 - val_loss: 0.1381 - val_accuracy: 0.9643
# Epoch 5/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2448 - accuracy: 0.9426 - val_loss: 0.1367 - val_accuracy: 0.9667
# Epoch 6/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2219 - accuracy: 0.9487 - val_loss: 0.1311 - val_accuracy: 0.9689
# Epoch 7/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.2105 - accuracy: 0.9497 - val_loss: 0.1332 - val_accuracy: 0.9681
# Epoch 8/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1994 - accuracy: 0.9524 - val_loss: 0.1261 - val_accuracy: 0.9703
# Epoch 9/25
# 118/118 [==============================] - 2s 18ms/step - loss: 0.1878 - accuracy: 0.9561 - val_loss: 0.1275 - val_accuracy: 0.9707
# Epoch 10/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1789 - accuracy: 0.9588 - val_loss: 0.1170 - val_accuracy: 0.9725
# Epoch 11/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1689 - accuracy: 0.9594 - val_loss: 0.1206 - val_accuracy: 0.9724
# Epoch 12/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1676 - accuracy: 0.9610 - val_loss: 0.1201 - val_accuracy: 0.9711
# Epoch 13/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1612 - accuracy: 0.9603 - val_loss: 0.1176 - val_accuracy: 0.9737
# Epoch 14/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1558 - accuracy: 0.9629 - val_loss: 0.1161 - val_accuracy: 0.9739
# Epoch 15/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1513 - accuracy: 0.9639 - val_loss: 0.1166 - val_accuracy: 0.9731
# Epoch 16/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1471 - accuracy: 0.9651 - val_loss: 0.1172 - val_accuracy: 0.9738
# Epoch 17/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1416 - accuracy: 0.9666 - val_loss: 0.1120 - val_accuracy: 0.9751
# Epoch 18/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1356 - accuracy: 0.9671 - val_loss: 0.1164 - val_accuracy: 0.9750
# Epoch 19/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1381 - accuracy: 0.9670 - val_loss: 0.1155 - val_accuracy: 0.9751
# Epoch 20/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1318 - accuracy: 0.9691 - val_loss: 0.1086 - val_accuracy: 0.9763
# Epoch 21/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1302 - accuracy: 0.9690 - val_loss: 0.1133 - val_accuracy: 0.9761
# Epoch 22/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1259 - accuracy: 0.9700 - val_loss: 0.1128 - val_accuracy: 0.9758
# Epoch 23/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1223 - accuracy: 0.9699 - val_loss: 0.1113 - val_accuracy: 0.9762
# Epoch 24/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1225 - accuracy: 0.9711 - val_loss: 0.1134 - val_accuracy: 0.9759
# Epoch 25/25
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1154 - accuracy: 0.9724 - val_loss: 0.1128 - val_accuracy: 0.9763

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
# plot_weights(model_with_dp)
plot_weights_hist(model_with_dp)
